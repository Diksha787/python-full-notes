# %%
int
float
string
list
tuple
dictionary
set

# %% [markdown]
# **String Questions**

# %%
##1. Split a string on a specific character
string = ('This is great').split(' ')
print(string)
# Out:
# ['This', 'is', 'great']

# %%
string = 'Hello 1 World 2'
vowels = ('a','e','i','o','u')
''.join([i for i in string if i not in vowels])
# Out:
# 'Hll 1 Wrld 2'

# %%
## Give an example of string slicing
string = 'I like to eat apples'

print(string[7:13])
# Out:
# to eat

# %%
## Replace all instances of a substring in a string
sentence = 'Sally sells sea shells by the sea shore'
sentence.replace('sea', 'mountain')
# Out:
# 'Sally sells mountain shells by the mountain shore'

# %%
def string_length(str):
    count = 0
    for i in str:
        count += 1
    return count
print(string_length('python is programming language'))
# Out:
# 30

# %%
string =['python is programming language'
string.len()
print(string)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-29-d70d2c292c25> in <module>()
#       1 string =['python is programming language']
# ----> 2 string.len()
#       3 print(string)
#
# AttributeError: 'list' object has no attribute 'len'

# %%
text=" python is a high-level, interpreted, general-purpose programming language. "
python ="python is a high-level"
text +" " + python
# Out:
# ' python is a high-level, interpreted, general-purpose programming language.  python is a high-level'

# %%
txt1 = "My name is {fname}, I'm {age}".format(fname = "preet", age = 36)
txt2 = "My name is {0}, I'm {1}".format("rita",36)
txt3 = "My name is {}, I'm {}".format("sita",36)

# %%
print(txt1)
print(txt2)
print(txt3)
# Out:
# My name is preet, I'm 36
# My name is rita, I'm 36
# My name is sita, I'm 36

# %%
## list question

# %%
## Turn every item of a list into its square
numbers = [1, 2, 3, 4, 5, 6, 7]
# result list
res = []
for i in numbers:
    # calculate square and add to the result list
    res.append(i * i)
print(res)
# Out:
# [1, 4, 9, 16, 25, 36, 49]

# %%
## Remove empty strings from the list of strings
list1 = ["pyhon", "", "java", "c", "", "ML"]

# remove None from list1 and convert result into list
res = list(filter(None, list1))
print(res)

# %%
##  Add new item to list after a specified item
list1 = [10, 20, [300, 400, [5000, 6000], 500], 30, 40]

# understand indexing
# list1[0] = 10
# list1[1] = 20
# list1[2] = [300, 400, [5000, 6000], 500]
# list1[2][2] = [5000, 6000]
# list1[2][2][1] = 6000


list1[2][2].append(7000)
print(list1)
# Out:
# [10, 20, [300, 400, [5000, 6000, 7000], 500], 30, 40]

# %%
## Replace list’s item with new value if found
list1 = [5, 10, 15, 20, 25, 50, 20]

# get the first occurrence index
index = list1.index(20)

# update item present at location
list1[index] = 200
print(list1)
# Out:
# [5, 10, 15, 200, 25, 50, 20]

# %%
## set questions

# %%
##Add a list of elements to a set
sample_set = {"Yellow", "Orange", "Black"}
sample_list = ["Blue", "Green", "Red"]

sample_set.update(sample_list)
print(sample_set)

# %%
##  Return a new set of identical items from two sets
set1 = {10, 20, 30, 40, 50}
set2 = {30, 40, 50, 60, 70}

print(set1.intersection(set2))

# %%
##  Update the first set with items that don’t exist in the second set
set1 = {10, 20, 30}
set2 = {20, 40, 50}

set1.difference_update(set2)
print(set1)
# Out:
# {10, 30}

# %%
##Check if two sets have any elements in common. If yes, display the common elements
set1 = {10, 20, 30, 40, 50}
set2 = {60, 70, 80, 90, 10}

if set1.isdisjoint(set2):
  print("Two sets have no items in common")
else:
  print("Two sets have items in common")
  print(set1.intersection(set2))
