# %% [markdown]
# **List Comprehension**

# %%
list_1 = [21,23,34,45,67,78,8,87,65,45,34,23]
divide_by_3=[]
for i in list_1:
  if i%3 == 0:
    divide_by_3.append(i)
print("without using list Comprehension:- ",divide_by_3)
# Out:
# without using list Comprehension:-  [21, 45, 78, 87, 45]

# %%
print("with using list Comprehension:- ",[i for i in list_1 if i%3 ==0])
# Out:
# with using list Comprehension:-  [21, 45, 78, 87, 45]

# %% [markdown]
# **Dictionary Comprehension**

# %%
newdict = {x: x**3 for x in range(10) if x**3 % 4 == 0}
print(newdict)
# Out:
# {0: 0, 2: 8, 4: 64, 6: 216, 8: 512}

# %%
keys = ['a','b','c','d','e']
values = [1,2,3,4,5]  
  
# but this line shows dict comprehension here  
myDict = { k:v for (k,v) in zip(keys, values)}  
  
# We can use below too
# myDict = dict(zip(keys, values))  
  
print (myDict)
# Out:
# {'a': 1, 'b': 2, 'c': 3, 'd': 4, 'e': 5}

# %%
sDict = {x.upper(): x*3 for x in 'coding '}
print (sDict)
# Out:
# {'C': 'ccc', 'O': 'ooo', 'D': 'ddd', 'I': 'iii', 'N': 'nnn', 'G': 'ggg', ' ': '   '}

# %%
# List Comprehension
list_comprehension = [i for i in range(11) if i % 2 == 0]
  
print(list_comprehension)
# Out:
# [0, 2, 4, 6, 8, 10]

# %%
# Generator Expression
generator_expression = (i for i in range(11) if i % 2 == 0)
  
print(generator_expression)
# Out:
# <generator object <genexpr> at 0x7fc6cbd938d0>

# %%
for i in generator_expression:
    print(i, end=" ")
